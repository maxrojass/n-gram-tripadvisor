# %%
import pandas as pd
tweets = pd.read_csv("/Users/maxrojas/Desktop/BI/3period/datasets/citihallv2.csv")
list(tweets.columns.values)
# Out:
# ['Text',
#  'Title',
#  'Rating',
#  'DateOfExperience',
#  'DateOfReview',
#  'Username',
#  'UserLocation',
#  'UserContribution',
#  'UserLikes']

# %%
tweets['Rating']=tweets['Rating'].fillna("")
tweets['DateOfExperience']=tweets['DateOfExperience'].fillna("")
tweets['UserLocation']=tweets['UserLocation'].fillna("")
tweets['UserContribution']=tweets['UserContribution'].fillna("")
tweets['UserLikes']=tweets['UserLikes'].fillna("")
tweets['Title']=tweets['Title'].fillna("")

tweets.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Text  \
# 0  Impressive building – if you like architecture, but sure to visit. Our tour guide was excellent, very knowledgeable. The shop is a good place to buy small gifts and souvenirs to bring home.
# 1  It is where Nobel Laureates have walked. This splendid building is only accessible with a guided tour. Tours are given in English but you must check the calendar to find the proper time the English tours are given as other language tours are also available. If you arrive at the City Hall before the tour begins, you can pay in SEK at that time. They have informational pamphlets in 15 languages available, as well.  The tour is about 50-60 minutes long and various parts of the building. The tour includes the history, architectural features, and many other interesting points. I found the tour guide fascinating in terms of knowledge and anecdotal commentary. The Gold Room features 5 carat gold tiles with motifs in gold mosaics. There is a WOW factor in many of the rooms. The Blue Room where the Nobel Banquet is held has a 10.00 pipe organ. The mythological paintings on the ceiling were unexpected but added to the fantasy.  The courtyard and gardens with many sculptures are a n added bonus. The 112 meter high City Hall tower can be climbed. It offers panoramic views of Stockholm and Lake Malaren.
# 2  We arrived at the city hall in the afternoon and their last tour started at 15 so we didn't get to it. There is a nice restaurant with great fikas and coffee. The view from the city hall is simply amazing!
# 3  It was fun to get caught up in the Nobel aura as told by our knowledgeable tour guide. The tour itself was only an hour which was just right for the rooms we saw which also included the city government seats. Amazing rooms!
# 4  The tour guids working at Statshuset are my favorites. The info presented in these tours is full of tid bits beyond just telling you about the building.
#
#                  Title  Rating DateOfExperience DateOfReview         Username  \
# 0  A Must See!          50      March 2020       Mar 2020     LaurelandDaniel
# 1  A Must See Landmark  40      October 2019     Mar 2020     duck8to
# 2  Amazing view         50      February 2020    Mar 2020     Teodora M
# 3  Nobel History        50      March 2020       Mar 2020     skymom
# 4  A SUPER tour.        50      March 2020       Mar 2020     invandare
#
#             UserLocation UserContribution UserLikes
# 0  Woodway, Texas         20               2
# 1  Montville, New Jersey  5,799            1,177
# 2  Brasov, Romania        14
# 3  Petoskey, Michigan     50               6
# 4  Stockholm, Sweden      78               43

# %%
stop = ['Slottstradgarden', 'ABBA','museum', 'city', 'hall', 'City', 'Hall','city hall' 'abba', 'abb', 'vas', 'vasa' 'stockholm', 'slottstradgarden ', 'Stockholm', 'Museum', 'museums', 'museet','museum ','stockholm']
tweets['Text'] = tweets['Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
tweets.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Text  \
# 0  Impressive building – if you like architecture, but sure to visit. Our tour guide was excellent, very knowledgeable. The shop is a good place to buy small gifts and souvenirs to bring home.
# 1  It is where Nobel Laureates have walked. This splendid building is only accessible with a guided tour. Tours are given in English but you must check the calendar to find the proper time the English tours are given as other language tours are also available. If you arrive at the before the tour begins, you can pay in SEK at that time. They have informational pamphlets in 15 languages available, as well. The tour is about 50-60 minutes long and various parts of the building. The tour includes the history, architectural features, and many other interesting points. I found the tour guide fascinating in terms of knowledge and anecdotal commentary. The Gold Room features 5 carat gold tiles with motifs in gold mosaics. There is a WOW factor in many of the rooms. The Blue Room where the Nobel Banquet is held has a 10.00 pipe organ. The mythological paintings on the ceiling were unexpected but added to the fantasy. The courtyard and gardens with many sculptures are a n added bonus. The 112 meter high tower can be climbed. It offers panoramic views of and Lake Malaren.
# 2  We arrived at the in the afternoon and their last tour started at 15 so we didn't get to it. There is a nice restaurant with great fikas and coffee. The view from the is simply amazing!
# 3  It was fun to get caught up in the Nobel aura as told by our knowledgeable tour guide. The tour itself was only an hour which was just right for the rooms we saw which also included the government seats. Amazing rooms!
# 4  The tour guids working at Statshuset are my favorites. The info presented in these tours is full of tid bits beyond just telling you about the building.
#
#                  Title  Rating DateOfExperience DateOfReview         Username  \
# 0  A Must See!          50      March 2020       Mar 2020     LaurelandDaniel
# 1  A Must See Landmark  40      October 2019     Mar 2020     duck8to
# 2  Amazing view         50      February 2020    Mar 2020     Teodora M
# 3  Nobel History        50      March 2020       Mar 2020     skymom
# 4  A SUPER tour.        50      March 2020       Mar 2020     invandare
#
#             UserLocation UserContribution UserLikes
# 0  Woodway, Texas         20               2
# 1  Montville, New Jersey  5,799            1,177
# 2  Brasov, Romania        14
# 3  Petoskey, Michigan     50               6
# 4  Stockholm, Sweden      78               43

# %%
import re, nltk
from nltk.stem import WordNetLemmatizer

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
wordnet_lemmatizer = WordNetLemmatizer()

def normalizer(tweet):
    only_letters = re.sub("[^a-zA-Z]", " ",tweet) 
    tokens = nltk.word_tokenize(only_letters)[2:]
    lower_case = [l.lower() for l in tokens]
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    lemmas = [wordnet_lemmatizer.lemmatize(t) for t in filtered_result]
    return lemmas

# %%
pd.set_option('display.max_colwidth', -1) # Setting this so we can see the full content of cells
tweets['normalized_tweet'] = tweets.Text.apply(normalizer)
tweets[['Text','normalized_tweet']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Text  \
# 0  Impressive building – if you like architecture, but sure to visit. Our tour guide was excellent, very knowledgeable. The shop is a good place to buy small gifts and souvenirs to bring home.
# 1  It is where Nobel Laureates have walked. This splendid building is only accessible with a guided tour. Tours are given in English but you must check the calendar to find the proper time the English tours are given as other language tours are also available. If you arrive at the before the tour begins, you can pay in SEK at that time. They have informational pamphlets in 15 languages available, as well. The tour is about 50-60 minutes long and various parts of the building. The tour includes the history, architectural features, and many other interesting points. I found the tour guide fascinating in terms of knowledge and anecdotal commentary. The Gold Room features 5 carat gold tiles with motifs in gold mosaics. There is a WOW factor in many of the rooms. The Blue Room where the Nobel Banquet is held has a 10.00 pipe organ. The mythological paintings on the ceiling were unexpected but added to the fantasy. The courtyard and gardens with many sculptures are a n added bonus. The 112 meter high tower can be climbed. It offers panoramic views of and Lake Malaren.
# 2  We arrived at the in the afternoon and their last tour started at 15 so we didn't get to it. There is a nice restaurant with great fikas and coffee. The view from the is simply amazing!
# 3  It was fun to get caught up in the Nobel aura as told by our knowledgeable tour guide. The tour itself was only an hour which was just right for the rooms we saw which also included the government seats. Amazing rooms!
# 4  The tour guids working at Statshuset are my favorites. The info presented in these tours is full of tid bits beyond just telling you about the building.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        normalized_tweet
# 0  [like, architecture, sure, visit, tour, guide, excellent, knowledgeable, shop, good, place, buy, small, gift, souvenir, bring, home]
# 1  [nobel, laureate, walked, splendid, building, accessible, guided, tour, tour, given, english, must, check, calendar, find, proper, time, english, tour, given, language, tour, also, available, arrive, tour, begin, pay, sek, time, informational, pamphlet, language, available, well, tour, minute, long, various, part, building, tour, includes, history, architectural, feature, many, interesting, point, found, tour, guide, fascinating, term, knowledge, anecdotal, commentary, gold, room, feature, carat, gold, tile, motif, gold, mosaic, wow, factor, many, room, blue, room, nobel, banquet, held, pipe, organ, mythological, painting, ceiling, unexpected, added, fantasy, courtyard, garden, many, sculpture, n, added, bonus, meter, high, tower, climbed, offer, panoramic, view, lake, malaren]
# 2  [afternoon, last, tour, started, get, nice, restaurant, great, fikas, coffee, view, simply, amazing]
# 3  [fun, get, caught, nobel, aura, told, knowledgeable, tour, guide, tour, hour, right, room, saw, also, included, government, seat, amazing, room]
# 4  [guids, working, statshuset, favorite, info, presented, tour, full, tid, bit, beyond, telling, building]

# %%
from nltk import ngrams

def ngrams(input_list):
    #onegrams = input_list
    bigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:]))]
    trigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:]))]
    fourgrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:], input_list[3:]))]
    return bigrams+trigrams
tweets['grams'] = tweets.normalized_tweet.apply(ngrams)
tweets[['grams']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           grams
# 0  [like architecture, architecture sure, sure visit, visit tour, tour guide, guide excellent, excellent knowledgeable, knowledgeable shop, shop good, good place, place buy, buy small, small gift, gift souvenir, souvenir bring, bring home, like architecture sure, architecture sure visit, sure visit tour, visit tour guide, tour guide excellent, guide excellent knowledgeable, excellent knowledgeable shop, knowledgeable shop good, shop good place, good place buy, place buy small, buy small gift, small gift souvenir, gift souvenir bring, souvenir bring home]
# 1  [nobel laureate, laureate walked, walked splendid, splendid building, building accessible, accessible guided, guided tour, tour tour, tour given, given english, english must, must check, check calendar, calendar find, find proper, proper time, time english, english tour, tour given, given language, language tour, tour also, also available, available arrive, arrive tour, tour begin, begin pay, pay sek, sek time, time informational, informational pamphlet, pamphlet language, language available, available well, well tour, tour minute, minute long, long various, various part, part building, building tour, tour includes, includes history, history architectural, architectural feature, feature many, many interesting, interesting point, point found, found tour, tour guide, guide fascinating, fascinating term, term knowledge, knowledge anecdotal, anecdotal commentary, commentary gold, gold room, room feature, feature carat, carat gold, gold tile, tile motif, motif gold, gold mosaic, mosaic wow, wow factor, factor many, many room, room blue, blue room, room nobel, nobel banquet, banquet held, held pipe, pipe organ, organ mythological, mythological painting, painting ceiling, ceiling unexpected, unexpected added, added fantasy, fantasy courtyard, courtyard garden, garden many, many sculpture, sculpture n, n added, added bonus, bonus meter, meter high, high tower, tower climbed, climbed offer, offer panoramic, panoramic view, view lake, lake malaren, nobel laureate walked, laureate walked splendid, ...]
# 2  [afternoon last, last tour, tour started, started get, get nice, nice restaurant, restaurant great, great fikas, fikas coffee, coffee view, view simply, simply amazing, afternoon last tour, last tour started, tour started get, started get nice, get nice restaurant, nice restaurant great, restaurant great fikas, great fikas coffee, fikas coffee view, coffee view simply, view simply amazing]
# 3  [fun get, get caught, caught nobel, nobel aura, aura told, told knowledgeable, knowledgeable tour, tour guide, guide tour, tour hour, hour right, right room, room saw, saw also, also included, included government, government seat, seat amazing, amazing room, fun get caught, get caught nobel, caught nobel aura, nobel aura told, aura told knowledgeable, told knowledgeable tour, knowledgeable tour guide, tour guide tour, guide tour hour, tour hour right, hour right room, right room saw, room saw also, saw also included, also included government, included government seat, government seat amazing, seat amazing room]
# 4  [guids working, working statshuset, statshuset favorite, favorite info, info presented, presented tour, tour full, full tid, tid bit, bit beyond, beyond telling, telling building, guids working statshuset, working statshuset favorite, statshuset favorite info, favorite info presented, info presented tour, presented tour full, tour full tid, full tid bit, tid bit beyond, bit beyond telling, beyond telling building]

# %%
import collections
def count_words(input):
    cnt = collections.Counter()
    for row in input:
        for word in row:
            cnt[word] += 1
    return cnt

# %%
tweets[['grams']].apply(count_words)['grams'].most_common(100)
# Out:
# [('nobel prize', 408),
#  ('guided tour', 381),
#  ('tour guide', 150),
#  ('gold room', 149),
#  ('well worth', 114),
#  ('worth visit', 106),
#  ('nobel banquet', 105),
#  ('prize banquet', 101),
#  ('banquet held', 97),
#  ('must see', 97),
#  ('prize dinner', 91),
#  ('nobel prize banquet', 87),
#  ('blue room', 84),
#  ('nobel prize dinner', 77),
#  ('beautiful building', 73),
#  ('great view', 73),
#  ('take place', 68),
#  ('golden room', 65),
#  ('gamla stan', 61),
#  ('take tour', 61),
#  ('dinner held', 59),
#  ('every year', 59),
#  ('place visit', 58),
#  ('prize winner', 56),
#  ('golden hall', 56),
#  ('tour english', 52),
#  ('old town', 50),
#  ('view city', 49),
#  ('nobel prize winner', 48),
#  ('blue hall', 48),
#  ('council chamber', 48),
#  ('nobel dinner', 43),
#  ('english tour', 42),
#  ('nice view', 41),
#  ('go tower', 41),
#  ('peace prize', 41),
#  ('climb tower', 41),
#  ('gold mosaic', 40),
#  ('room nobel', 40),
#  ('prize banquet held', 39),
#  ('take guided', 39),
#  ('take guided tour', 39),
#  ('annual nobel', 39),
#  ('well worth visit', 38),
#  ('go inside', 38),
#  ('guide knowledgeable', 38),
#  ('make sure', 38),
#  ('top tower', 37),
#  ('walk around', 37),
#  ('nobel banquet held', 36),
#  ('highly recommend', 36),
#  ('prize dinner held', 36),
#  ('gift shop', 36),
#  ('view stockholm', 35),
#  ('great place', 35),
#  ('noble prize', 34),
#  ('definitely worth', 34),
#  ('building beautiful', 33),
#  ('tour take', 33),
#  ('place nobel', 32),
#  ('mosaic tile', 32),
#  ('tour building', 31),
#  ('year old', 31),
#  ('view top', 31),
#  ('tour group', 31),
#  ('tour hall', 30),
#  ('nobel laureate', 29),
#  ('red brick', 29),
#  ('see nobel', 29),
#  ('view across', 28),
#  ('nobel price', 28),
#  ('impressive building', 28),
#  ('prize awarded', 28),
#  ('amazing view', 27),
#  ('nobel peace', 26),
#  ('worth visiting', 26),
#  ('visit guided', 26),
#  ('view tower', 26),
#  ('visit stockholm', 26),
#  ('tour see', 25),
#  ('building also', 25),
#  ('held every', 25),
#  ('see stockholm', 25),
#  ('worth time', 25),
#  ('good view', 25),
#  ('central station', 24),
#  ('tour inside', 24),
#  ('interesting building', 24),
#  ('nobel peace prize', 24),
#  ('golden mosaic', 24),
#  ('blue nobel', 24),
#  ('buy ticket', 24),
#  ('tower tour', 24),
#  ('highly recommended', 24),
#  ('beautiful view', 23),
#  ('tour interesting', 23),
#  ('tour tower', 23),
#  ('inside building', 23),
#  ('prize ceremony', 23),
#  ('tour well', 23)]
