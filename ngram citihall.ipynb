# %%
import pandas as pd
tweets = pd.read_csv("/Users/maxrojas/Desktop/BI/3 period/citihallv2.csv")
list(tweets.columns.values)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-61157918260a> in <module>
#       1 import pandas as pd
# ----> 2 tweets = pd.read_csv("/Users/maxrojas/Desktop/BI/3 period/citihallv2.csv")
#       3 list(tweets.columns.values)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/Users/maxrojas/Desktop/BI/3 period/citihallv2.csv' does not exist: b'/Users/maxrojas/Desktop/BI/3 period/citihallv2.csv'

# %%
tweets['Rating']=tweets['Rating'].fillna("")
tweets['DateOfExperience']=tweets['DateOfExperience'].fillna("")
tweets['UserLocation']=tweets['UserLocation'].fillna("")
tweets['UserContribution']=tweets['UserContribution'].fillna("")
tweets['UserLikes']=tweets['UserLikes'].fillna("")
tweets['Title']=tweets['Title'].fillna("")

tweets.head()
# Out:
#                                                 Text  \
# 0  Vasa museum is much different than any other m...
# 1  I am not a great fan of boats or naval history...
# 2  If you love history, you will love this museum...
# 3  While doing research, the Vasamuseet has been ...
# 4  Everyone said "you must go see Vasa" but it's ...
#
#                                     Title Rating DateOfExperience  \
# 0                A very impressive museum     50    February 2020
# 1  Stunning museum - a Stockholm must see     50    February 2020
# 2               Best museum in Stockholm      50    February 2020
# 3                      Very educational!      50    February 2020
# 4                                Stunning     50    November 2019
#
#           Username            UserLocation  UserContribution UserLikes
# 0           Denisp   Nea Erithraia, Greece                80        37
# 1        mfb632016  London, United Kingdom                19        17
# 2  elizabethvcliff   Leeds, United Kingdom                17
# 3          yiuyiut        Hong Kong, China                34         7
# 4     woolwich_boy     Adelaide, Australia                29        11

# %%
stop = ['Vasa','museum', 'stockholm', 'vasa', 'Stockholm', 'Museum', 'museums', 'museet','museum ','stockholm']
tweets['Text'] = tweets['Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
tweets.head()
# Out:
#                                                 Text  \
# 0  is much different than any other you may have ...
# 1  I am not a great fan of boats or naval history...
# 2  If you love history, you will love this museum...
# 3  While doing research, the Vasamuseet has been ...
# 4  Everyone said "you must go see Vasa" but it's ...
#
#                                     Title Rating DateOfExperience  \
# 0                A very impressive museum     50    February 2020
# 1  Stunning museum - a Stockholm must see     50    February 2020
# 2               Best museum in Stockholm      50    February 2020
# 3                      Very educational!      50    February 2020
# 4                                Stunning     50    November 2019
#
#           Username            UserLocation  UserContribution UserLikes
# 0           Denisp   Nea Erithraia, Greece                80        37
# 1        mfb632016  London, United Kingdom                19        17
# 2  elizabethvcliff   Leeds, United Kingdom                17
# 3          yiuyiut        Hong Kong, China                34         7
# 4     woolwich_boy     Adelaide, Australia                29        11

# %%
import re, nltk
from nltk.stem import WordNetLemmatizer

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
wordnet_lemmatizer = WordNetLemmatizer()

def normalizer(tweet):
    only_letters = re.sub("[^a-zA-Z]", " ",tweet) 
    tokens = nltk.word_tokenize(only_letters)[2:]
    lower_case = [l.lower() for l in tokens]
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    lemmas = [wordnet_lemmatizer.lemmatize(t) for t in filtered_result]
    return lemmas

# %%
nltk.download('punkt')
nltk.download('wordnet')
normalizer("Here is text about an airline I.")
# Out:
# [nltk_data] Downloading package punkt to /Users/maxrojas/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/maxrojas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['text', 'airline']

# %%
pd.set_option('display.max_colwidth', -1) # Setting this so we can see the full content of cells
tweets['normalized_tweet'] = tweets.Text.apply(normalizer)
tweets[['Text','normalized_tweet']].head()
# Out:
#                                                                                                                                                                                                                                                                     Text  \
# 0  is much different than any other you may have visited in the past. It's well made and very impressive. The fact that you get to approach such an old ship wreck is really unique.
# 1  I am not a great fan of boats or naval history. But this is so much more. The itself is a stunning sight – it is difficult to imagine how awe inspiring she must have appeared on her maiden voyage. The detail of the...More
# 2  If you love history, you will love this museum. For any brits that loved the Mary Rose in Portsmouth, you will be gobsmacked by the Vasa. The is well organised with free guides at certain times of the day in numerous languages. Theres also...More
# 3  While doing research, the Vasamuseet has been recommended by many other visitors. I agree it’s one of the that is a must-go in Stockholm. Remember to try to catch a guided tour (included in admission fee) because the history and details that these guides...More
# 4  Everyone said "you must go see Vasa" but it's just an old boat right? The trip on the tram in the steady drizzle did not help to set expectations high, the entrance to the is relatively low key and there were not many people...More
#
#                                                                                                                                                             normalized_tweet
# 0  [different, may, visited, past, well, made, impressive, fact, get, approach, old, ship, wreck, really, unique]
# 1  [great, fan, boat, naval, history, much, stunning, sight, difficult, imagine, awe, inspiring, must, appeared, maiden, voyage, detail]
# 2  [love, history, love, museum, brit, loved, mary, rose, portsmouth, gobsmacked, vas, well, organised, free, guide, certain, time, day, numerous, language, there, also]
# 3  [research, vasamuseet, recommended, many, visitor, agree, one, must, go, stockholm, remember, try, catch, guided, tour, included, admission, fee, history, detail, guide]
# 4  [must, go, see, vas, old, boat, right, trip, tram, steady, drizzle, help, set, expectation, high, entrance, relatively, low, key, many, people]

# %%
from nltk import ngrams

def ngrams(input_list):
    #onegrams = input_list
    bigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:]))]
    trigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:]))]
    fourgrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:], input_list[3:]))]
    return bigrams+trigrams+fourgrams
tweets['grams'] = tweets.normalized_tweet.apply(ngrams)
tweets[['grams']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       grams
# 0  [different may, may visited, visited past, past well, well made, made impressive, impressive fact, fact get, get approach, approach old, old ship, ship wreck, wreck really, really unique, different may visited, may visited past, visited past well, past well made, well made impressive, made impressive fact, impressive fact get, fact get approach, get approach old, approach old ship, old ship wreck, ship wreck really, wreck really unique, different may visited past, may visited past well, visited past well made, past well made impressive, well made impressive fact, made impressive fact get, impressive fact get approach, fact get approach old, get approach old ship, approach old ship wreck, old ship wreck really, ship wreck really unique]
# %%
import collections
def count_words(input):
    cnt = collections.Counter()
    for row in input:
        for word in row:
            cnt[word] += 1
    return cnt

# %%
tweets[['grams']].apply(count_words)['grams'].most_common(100)
# Out:
# [('must see', 314),
#  ('guided tour', 294),
#  ('th century', 242),
#  ('maiden voyage', 232),
#  ('worth visit', 203),
#  ('well preserved', 182),
#  ('well worth', 176),
#  ('see ship', 145),
#  ('old ship', 132),
#  ('ship sank', 120),
#  ('well done', 112),
#  ('year old', 112),
#  ('history ship', 107),
#  ('see stockholm', 99),
#  ('year ago', 93),
#  ('visit stockholm', 90),
#  ('around ship', 90),
#  ('ship amazing', 89),
#  ('free guided', 80),
#  ('well worth visit', 78),
#  ('free tour', 77),
#  ('free guided tour', 77),
#  ('sank maiden', 77),
#  ('century ship', 76),
#  ('ship well', 76),
#  ('visit museum', 75),
#  ('must see stockholm', 75),
#  ('highly recommend', 75),
#  ('sank maiden voyage', 74),
#  ('th century ship', 72),
#  ('story ship', 70),
#  ('must visit', 69),
#  ('war ship', 68),
#  ('ship sunk', 66),
#  ('definitely worth', 65),
#  ('built around', 64),
#  ('spend hour', 63),
#  ('preserved ship', 62),
#  ('well laid', 61),
#  ('make sure', 61),
#  ('tour guide', 60),
#  ('story behind', 60),
#  ('spent hour', 59),
#  ('amazing see', 58),
#  ('one best', 58),
#  ('couple hour', 57),
#  ('really interesting', 53),
#  ('amazing ship', 53),
#  ('would recommend', 53),
#  ('place visit', 52),
#  ('ship impressive', 51),
#  ('lot information', 51),
#  ('walk around', 50),
#  ('visiting stockholm', 50),
#  ('tour english', 50),
#  ('size ship', 50),
#  ('viking ship', 49),
#  ('huge ship', 49),
#  ('ship history', 48),
#  ('well presented', 48),
#  ('sheer size', 43),
#  ('swedish history', 43),
#  ('ship huge', 42),
#  ('highly recommended', 42),
#  ('interesting story', 42),
#  ('museum ship', 42),
#  ('sunk maiden', 41),
#  ('ship interesting', 41),
#  ('piece history', 40),
#  ('century warship', 39),
#  ('blown away', 39),
#  ('ship built', 39),
#  ('sunk maiden voyage', 38),
#  ('ship really', 38),
#  ('different level', 38),
#  ('audio guide', 37),
#  ('stockholm ship', 37),
#  ('ship preserved', 37),
#  ('mary rose', 36),
#  ('amazing story', 36),
#  ('definitely worth visit', 36),
#  ('ship story', 36),
#  ('year old ship', 35),
#  ('hundred year', 35),
#  ('th century warship', 35),
#  ('short film', 35),
#  ('one ship', 34),
#  ('big ship', 33),
#  ('bottom sea', 33),
#  ('much see', 33),
#  ('ship well preserved', 33),
#  ('year later', 32),
#  ('sailing ship', 32),
#  ('english tour', 32),
#  ('lot see', 31),
#  ('history behind', 31),
#  ('least hour', 31),
#  ('worth time', 31),
#  ('attraction stockholm', 31),
#  ('ship incredible', 30)]
