# %%
import pandas as pd
tweets = pd.read_csv("DjugardenClean.csv")
list(tweets.columns.values)
# Out:
# ['Unnamed: 0',
#  'Text',
#  'Title',
#  'Rating',
#  'DateOfExperience',
#  'DateOfReview',
#  'Username',
#  'UserLocation',
#  'UserContribution',
#  'UserLikes']

# %%
tweets['Rating']=tweets['Rating'].fillna("")
tweets['DateOfExperience']=tweets['DateOfExperience'].fillna("")
tweets['UserLocation']=tweets['UserLocation'].fillna("")
tweets['UserContribution']=tweets['UserContribution'].fillna("")
tweets['UserLikes']=tweets['UserLikes'].fillna("")
tweets['Title']=tweets['Title'].fillna("")

tweets.head()
# Out:
#    Unnamed: 0                                               Text  \
# 0           0  We spent the entire afternoon strolling around...
# 1           1  Ferry will go to that place , and ferry will b...
# 2           2  There's tons of famous tourist destinations ou...
# 3           3  One of the most beautiful islands of Stockholm...
# 4           4  Bundle up. Even in the dead of winter this is ...
#
#                                             Title  Rating DateOfExperience  \
# 0             A Pleasant Walk in a Beautiful Park      50         May 2019
# 1                                  Peaceful Place      50       March 2020
# 2           Especially Love the Royal Greenhouses      50       March 2020
# 3  One of the most beautiful islands of Stockholm      40    November 2019
# 4                 Light snow and clear blue skies      50    February 2020
#
#   DateOfReview                      Username         UserLocation  \
# 0     Apr 2020                     AllegraLC    Puchong, Malaysia
# 1     Mar 2020                       alpha08        Jaipur, India
# 2     Mar 2020                     invandare    Stockholm, Sweden
# 3     Mar 2020                         rselb  Kongsvinger, Norway
# 4     Mar 2020  An American living in Europe
#
#   UserContribution UserLikes
# 0              419        31
# 1              118        12
# 2               78        43
# 3                3
# 4               13

# %%
stop = ['Slottstradgarden','museum', 'abba', 'abb', 'vas', 'vasa' 'stockholm', 'slottstradgarden ', 'Stockholm', 'Museum', 'museums', 'museet','museum ','stockholm']
tweets['Text'] = tweets['Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
tweets.head()
# Out:
#    Unnamed: 0                                               Text  \
# 0           0  We spent the entire afternoon strolling around...
# 1           1  Ferry will go to that place , and ferry will b...
# 2           2  There's tons of famous tourist destinations ou...
# 3           3  One of the most beautiful islands of Stockholm...
# 4           4  Bundle up. Even in the dead of winter this is ...
#
#                                             Title  Rating DateOfExperience  \
# 0             A Pleasant Walk in a Beautiful Park      50         May 2019
# 1                                  Peaceful Place      50       March 2020
# 2           Especially Love the Royal Greenhouses      50       March 2020
# 3  One of the most beautiful islands of Stockholm      40    November 2019
# 4                 Light snow and clear blue skies      50    February 2020
#
#   DateOfReview                      Username         UserLocation  \
# 0     Apr 2020                     AllegraLC    Puchong, Malaysia
# 1     Mar 2020                       alpha08        Jaipur, India
# 2     Mar 2020                     invandare    Stockholm, Sweden
# 3     Mar 2020                         rselb  Kongsvinger, Norway
# 4     Mar 2020  An American living in Europe
#
#   UserContribution UserLikes
# 0              419        31
# 1              118        12
# 2               78        43
# 3                3
# 4               13

# %%
import re, nltk
from nltk.stem import WordNetLemmatizer

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
wordnet_lemmatizer = WordNetLemmatizer()

def normalizer(tweet):
    only_letters = re.sub("[^a-zA-Z]", " ",tweet) 
    tokens = nltk.word_tokenize(only_letters)[2:]
    lower_case = [l.lower() for l in tokens]
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    lemmas = [wordnet_lemmatizer.lemmatize(t) for t in filtered_result]
    return lemmas

# %%
pd.set_option('display.max_colwidth', -1) # Setting this so we can see the full content of cells
tweets['normalized_tweet'] = tweets.Text.apply(normalizer)
tweets[['Text','normalized_tweet']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Text  \
# 0  We spent the entire afternoon strolling around the area but it was impossible to cover all. It is basically an island which also houses the famous Vasa Museum. We planned according to the map and started from Vasa along the northern shoreline. It was not crowded at all and the weather was nice. It was a time to enjoy the nature, the scenic waterfront promenade, and the cool crisp air. We walked towards the east to Rosendals Trädgård, and back to our starting point, clockwise. We passed by some historical buildings, museums, restaurants, cafes, and an amusement park. We spent some time at Rosendals Trädgård, a garden with a café.
# 1  Ferry will go to that place , and ferry will be there in 15 minutes each time slot. A very beautiful place with a beautiful weather you can walk there and can sit near a ship which was everywhere there
# 2  There's tons of famous tourist destinations out on Djurgården but us locals' favorite place is the Royal greenhouses where they grow the flowers and veggies for the various castle gardens around Stockholm. There are plants for sale and a cafe' ov course but there is also a wine kiosk. And don't miss the Labrynth. A small one but fun to go through no matter. The walk there and back, a loop walk, is a wonderful way to spend a few hours chatting with your friends, family, or visitors.
# 3  One of the most beautiful islands of Stockholm, a moment of relaxation and peaceful stroll after the hustle and bustle of the shopping streets and the historic center between parks and monuments, a moment out of time, to be visited at various times of the year for colors and games of lights between the foliage of the trees.
# 4  Bundle up. Even in the dead of winter this is a wonderful place to amble. Uncrowded. Many interesting historic buildings. Scenic views. Don't forget your camera!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   normalized_tweet
# 0  [entire, afternoon, strolling, around, area, impossible, cover, basically, island, also, house, famous, vas, museum, planned, according, map, started, vas, along, northern, shoreline, crowded, weather, nice, time, enjoy, nature, scenic, waterfront, promenade, cool, crisp, air, walked, towards, east, rosendals, tr, dg, rd, back, starting, point, clockwise, passed, historical, building, museum, restaurant, cafe, amusement, park, spent, time, rosendals, tr, dg, rd, garden, caf]
# 1  [go, place, ferry, minute, time, slot, beautiful, place, beautiful, weather, walk, sit, near, ship, everywhere]
# 2  [ton, famous, tourist, destination, djurg, rden, u, local, favorite, place, royal, greenhouse, grow, flower, veggie, various, castle, garden, around, stockholm, plant, sale, cafe, ov, course, also, wine, kiosk, miss, labrynth, small, one, fun, go, matter, walk, back, loop, walk, wonderful, way, spend, hour, chatting, friend, family, visitor]
# 3  [beautiful, island, stockholm, moment, relaxation, peaceful, stroll, hustle, bustle, shopping, street, historic, center, park, monument, moment, time, visited, various, time, year, color, game, light, foliage, tree]
# 4  [even, dead, winter, wonderful, place, amble, uncrowded, many, interesting, historic, building, scenic, view, forget, camera]

# %%
from nltk import ngrams

def ngrams(input_list):
    #onegrams = input_list
    bigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:]))]
    trigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:]))]
    fourgrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:], input_list[3:]))]
    return bigrams+trigrams+fourgrams
tweets['grams'] = tweets.normalized_tweet.apply(ngrams)
tweets[['grams']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 grams
# 0  [entire afternoon, afternoon strolling, strolling around, around area, area impossible, impossible cover, cover basically, basically island, island also, also house, house famous, famous vas, vas museum, museum planned, planned according, according map, map started, started vas, vas along, along northern, northern shoreline, shoreline crowded, crowded weather, weather nice, nice time, time enjoy, enjoy nature, nature scenic, scenic waterfront, waterfront promenade, promenade cool, cool crisp, crisp air, air walked, walked towards, towards east, east rosendals, rosendals tr, tr dg, dg rd, rd back, back starting, starting point, point clockwise, clockwise passed, passed historical, historical building, building museum, museum restaurant, restaurant cafe, cafe amusement, amusement park, park spent, spent time, time rosendals, rosendals tr, tr dg, dg rd, rd garden, garden caf, entire afternoon strolling, afternoon strolling around, strolling around area, around area impossible, area impossible cover, impossible cover basically, cover basically island, basically island also, island also house, also house famous, house famous vas, famous vas museum, vas museum planned, museum planned according, planned according map, according map started, map started vas, started vas along, vas along northern, along northern shoreline, northern shoreline crowded, shoreline crowded weather, crowded weather nice, weather nice time, nice time enjoy, time enjoy nature, enjoy nature scenic, nature scenic waterfront, scenic waterfront promenade, waterfront promenade cool, promenade cool crisp, cool crisp air, crisp air walked, air walked towards, walked towards east, towards east rosendals, east rosendals tr, rosendals tr dg, tr dg rd, dg rd back, ...]
# 1  [go place, place ferry, ferry minute, minute time, time slot, slot beautiful, beautiful place, place beautiful, beautiful weather, weather walk, walk sit, sit near, near ship, ship everywhere, go place ferry, place ferry minute, ferry minute time, minute time slot, time slot beautiful, slot beautiful place, beautiful place beautiful, place beautiful weather, beautiful weather walk, weather walk sit, walk sit near, sit near ship, near ship everywhere, go place ferry minute, place ferry minute time, ferry minute time slot, minute time slot beautiful, time slot beautiful place, slot beautiful place beautiful, beautiful place beautiful weather, place beautiful weather walk, beautiful weather walk sit, weather walk sit near, walk sit near ship, sit near ship everywhere]
# 2  [ton famous, famous tourist, tourist destination, destination djurg, djurg rden, rden u, u local, local favorite, favorite place, place royal, royal greenhouse, greenhouse grow, grow flower, flower veggie, veggie various, various castle, castle garden, garden around, around stockholm, stockholm plant, plant sale, sale cafe, cafe ov, ov course, course also, also wine, wine kiosk, kiosk miss, miss labrynth, labrynth small, small one, one fun, fun go, go matter, matter walk, walk back, back loop, loop walk, walk wonderful, wonderful way, way spend, spend hour, hour chatting, chatting friend, friend family, family visitor, ton famous tourist, famous tourist destination, tourist destination djurg, destination djurg rden, djurg rden u, rden u local, u local favorite, local favorite place, favorite place royal, place royal greenhouse, royal greenhouse grow, greenhouse grow flower, grow flower veggie, flower veggie various, veggie various castle, various castle garden, castle garden around, garden around stockholm, around stockholm plant, stockholm plant sale, plant sale cafe, sale cafe ov, cafe ov course, ov course also, course also wine, also wine kiosk, wine kiosk miss, kiosk miss labrynth, miss labrynth small, labrynth small one, small one fun, one fun go, fun go matter, go matter walk, matter walk back, walk back loop, back loop walk, loop walk wonderful, walk wonderful way, wonderful way spend, way spend hour, spend hour chatting, hour chatting friend, chatting friend family, friend family visitor, ton famous tourist destination, famous tourist destination djurg, tourist destination djurg rden, destination djurg rden u, djurg rden u local, rden u local favorite, u local favorite place, local favorite place royal, favorite place royal greenhouse, ...]
# 3  [beautiful island, island stockholm, stockholm moment, moment relaxation, relaxation peaceful, peaceful stroll, stroll hustle, hustle bustle, bustle shopping, shopping street, street historic, historic center, center park, park monument, monument moment, moment time, time visited, visited various, various time, time year, year color, color game, game light, light foliage, foliage tree, beautiful island stockholm, island stockholm moment, stockholm moment relaxation, moment relaxation peaceful, relaxation peaceful stroll, peaceful stroll hustle, stroll hustle bustle, hustle bustle shopping, bustle shopping street, shopping street historic, street historic center, historic center park, center park monument, park monument moment, monument moment time, moment time visited, time visited various, visited various time, various time year, time year color, year color game, color game light, game light foliage, light foliage tree, beautiful island stockholm moment, island stockholm moment relaxation, stockholm moment relaxation peaceful, moment relaxation peaceful stroll, relaxation peaceful stroll hustle, peaceful stroll hustle bustle, stroll hustle bustle shopping, hustle bustle shopping street, bustle shopping street historic, shopping street historic center, street historic center park, historic center park monument, center park monument moment, park monument moment time, monument moment time visited, moment time visited various, time visited various time, visited various time year, various time year color, time year color game, year color game light, color game light foliage, game light foliage tree]
# 4  [even dead, dead winter, winter wonderful, wonderful place, place amble, amble uncrowded, uncrowded many, many interesting, interesting historic, historic building, building scenic, scenic view, view forget, forget camera, even dead winter, dead winter wonderful, winter wonderful place, wonderful place amble, place amble uncrowded, amble uncrowded many, uncrowded many interesting, many interesting historic, interesting historic building, historic building scenic, building scenic view, scenic view forget, view forget camera, even dead winter wonderful, dead winter wonderful place, winter wonderful place amble, wonderful place amble uncrowded, place amble uncrowded many, amble uncrowded many interesting, uncrowded many interesting historic, many interesting historic building, interesting historic building scenic, historic building scenic view, building scenic view forget, scenic view forget camera]

# %%
import collections
def count_words(input):
    cnt = collections.Counter()
    for row in input:
        for word in row:
            cnt[word] += 1
    return cnt

# %%
tweets[['grams']].apply(count_words)['grams'].most_common(100)
# Out:
# [('djurg rden', 119),
#  ('amusement park', 113),
#  ('vas museum', 86),
#  ('abba museum', 73),
#  ('walk around', 69),
#  ('gr na', 67),
#  ('na lund', 65),
#  ('gr na lund', 65),
#  ('open air', 58),
#  ('gamla stan', 46),
#  ('great place', 41),
#  ('around island', 40),
#  ('spend day', 31),
#  ('grona lund', 31),
#  ('along water', 29),
#  ('walk along', 29),
#  ('nice place', 29),
#  ('sunny day', 29),
#  ('long walk', 28),
#  ('place visit', 26),
#  ('museum skansen', 25),
#  ('lund amusement', 25),
#  ('lund amusement park', 25),
#  ('must see', 25),
#  ('vas abba', 24),
#  ('beautiful place', 23),
#  ('place walk', 23),
#  ('great view', 23),
#  ('nice walk', 23),
#  ('skansen open', 22),
#  ('walking around', 22),
#  ('well worth', 21),
#  ('museum vas', 21),
#  ('nordic museum', 21),
#  ('air museum', 20),
#  ('open air museum', 20),
#  ('skansen vas', 20),
#  ('skansen open air', 20),
#  ('city centre', 20),
#  ('one day', 20),
#  ('place take', 19),
#  ('much see', 19),
#  ('part stockholm', 19),
#  ('old town', 19),
#  ('museum abba', 18),
#  ('central stockholm', 18),
#  ('worth visit', 18),
#  ('park gr', 18),
#  ('bus tram', 18),
#  ('beautiful island', 17),
#  ('take tram', 17),
#  ('green area', 17),
#  ('really nice', 16),
#  ('rent bike', 16),
#  ('whole day', 16),
#  ('amusement park gr', 16),
#  ('park gr na', 16),
#  ('park gr na lund', 16),
#  ('beautiful nature', 15),
#  ('vas abba museum', 15),
#  ('visit vas', 15),
#  ('take walk', 15),
#  ('museum vas museum', 15),
#  ('nice view', 15),
#  ('walking distance', 15),
#  ('visit skansen', 15),
#  ('ferry slussen', 14),
#  ('city center', 14),
#  ('many attraction', 14),
#  ('theme park', 14),
#  ('park skansen', 14),
#  ('amusement park gr na', 14),
#  ('highly recommend', 14),
#  ('close city', 14),
#  ('take bus', 13),
#  ('walking path', 13),
#  ('blue gate', 13),
#  ('park beautiful', 13),
#  ('ice cream', 13),
#  ('visit stockholm', 13),
#  ('half day', 13),
#  ('cafe restaurant', 13),
#  ('tram bus', 13),
#  ('nordiska museet', 13),
#  ('must visit', 13),
#  ('around djurgarden', 13),
#  ('take ferry', 13),
#  ('grona lund amusement', 13),
#  ('grona lund amusement park', 13),
#  ('tr dg', 12),
#  ('hustle bustle', 12),
#  ('wonderful place', 12),
#  ('ferry gamla', 12),
#  ('green space', 12),
#  ('place eat', 12),
#  ('beautiful area', 12),
#  ('spend time', 12),
#  ('museum amusement', 12),
#  ('museum amusement park', 12),
#  ('around park', 12)]
