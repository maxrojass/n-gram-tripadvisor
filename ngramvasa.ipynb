# %%
import pandas as pd
tweets = pd.read_csv("/Users/maxrojas/Desktop/BI/3period/datasets/vasa.csv")
list(tweets.columns.values)
# Out:
# ['Text',
#  'Title',
#  'Rating',
#  'DateOfExperience',
#  'DateOfReview',
#  'Username',
#  'UserLocation',
#  'UserContribution',
#  'UserLikes']

# %%
tweets['Rating']=tweets['Rating'].fillna("")
tweets['DateOfExperience']=tweets['DateOfExperience'].fillna("")
tweets['UserLocation']=tweets['UserLocation'].fillna("")
tweets['UserContribution']=tweets['UserContribution'].fillna("")
tweets['UserLikes']=tweets['UserLikes'].fillna("")
tweets['Title']=tweets['Title'].fillna("")

tweets.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Text  \
# 0  If you are ever in Stockholm, these two museums, which are right next to each other, are a must. The vasa is a ship that was pulled from the icy waters and is completely preserved and very ornate. If you are ever in Stockholm I recommend an afternoon at these museums.
# 1  Really interesting and so well organised with enough information but not too much! The ship itself is fascinating and I appreciated the exhibition focusing on the women's roles.
# 2  We planned 2 hours for Vasa museum but it was so interesting we forgot to leave. Vasa museum it's a MUST in Stocholm. You can learn all about the fully intact 17th century ship and about Sweden's history.
# 3  It was a very nice experience being there.The ship was huge and astonishing and u can see it from different heights and angles.All the museum was built around the ship and the story is very interesting.You can go there for sure ,the fee is around 15 euro.There were also some rooms/walls with things related to the ship which had their one interest!Also there is some guides appearing every 30 minutes making their guided tours every 30 minutes in a lot of languages(not greek unfortunately).
# 4  Travelling with my 11 year old and wanted to do something that “ ticked all the boxes “ . Whilst he had reservations , it was thoroughly enjoyed . Whilst there were not many people due to the world wide virus issue , there staff were extremely interesting and informative . It is one heck of a story including the nature of the sinking , recovery, restoration , preservation etc .  Recommend it for anyone remotely interested in this kind of stuff .  Allocate at least 3 hours for this and that was without allowing for queues .
#
#                            Title  Rating DateOfExperience DateOfReview  \
# 0  Vasa museum and Nordic museum  50      March 2020       Mar 22
# 1  Well worth a visit.            50      March 2020       Mar 18
# 2  Awesome swedish history        50      February 2020    Mar 18
# 3  Vasa Museum-Something Special  40      March 2020       Mar 14
# 4  Very interesting               40      March 2020       Mar 14
#
#            Username              UserLocation UserContribution UserLikes
# 0  Travelin' Woman                             5
# 1  GoldfinchSuffolk  Suffolk                   21               10
# 2  Teodora M         Brasov, Romania           15
# 3  Patsa                                       7
# 4  Gavin F           Aberdeen, United Kingdom  91               10

# %%
stop = ['Slottstradgarden', 'ABBA','museum', 'city', 'hall', 'City', 'Hall','city hall' 'abba', 'abb', 'vas', 'vasa' 'stockholm', 'slottstradgarden ', 'Stockholm', 'Museum', 'museums', 'museet','museum ','stockholm']
tweets['Text'] = tweets['Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
tweets.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Text  \
# 0  If you are ever in Stockholm, these two museums, which are right next to each other, are a must. The vasa is a ship that was pulled from the icy waters and is completely preserved and very ornate. If you are ever in I recommend an afternoon at these museums.
# 1  Really interesting and so well organised with enough information but not too much! The ship itself is fascinating and I appreciated the exhibition focusing on the women's roles.
# 2  We planned 2 hours for Vasa but it was so interesting we forgot to leave. Vasa it's a MUST in Stocholm. You can learn all about the fully intact 17th century ship and about Sweden's history.
# 3  It was a very nice experience being there.The ship was huge and astonishing and u can see it from different heights and angles.All the was built around the ship and the story is very interesting.You can go there for sure ,the fee is around 15 euro.There were also some rooms/walls with things related to the ship which had their one interest!Also there is some guides appearing every 30 minutes making their guided tours every 30 minutes in a lot of languages(not greek unfortunately).
# 4  Travelling with my 11 year old and wanted to do something that “ ticked all the boxes “ . Whilst he had reservations , it was thoroughly enjoyed . Whilst there were not many people due to the world wide virus issue , there staff were extremely interesting and informative . It is one heck of a story including the nature of the sinking , recovery, restoration , preservation etc . Recommend it for anyone remotely interested in this kind of stuff . Allocate at least 3 hours for this and that was without allowing for queues .
#
#                            Title  Rating DateOfExperience DateOfReview  \
# 0  Vasa museum and Nordic museum  50      March 2020       Mar 22
# 1  Well worth a visit.            50      March 2020       Mar 18
# 2  Awesome swedish history        50      February 2020    Mar 18
# 3  Vasa Museum-Something Special  40      March 2020       Mar 14
# 4  Very interesting               40      March 2020       Mar 14
#
#            Username              UserLocation UserContribution UserLikes
# 0  Travelin' Woman                             5
# 1  GoldfinchSuffolk  Suffolk                   21               10
# 2  Teodora M         Brasov, Romania           15
# 3  Patsa                                       7
# 4  Gavin F           Aberdeen, United Kingdom  91               10

# %%
import re, nltk
from nltk.stem import WordNetLemmatizer

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
wordnet_lemmatizer = WordNetLemmatizer()

def normalizer(tweet):
    only_letters = re.sub("[^a-zA-Z]", " ",tweet) 
    tokens = nltk.word_tokenize(only_letters)[2:]
    lower_case = [l.lower() for l in tokens]
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    lemmas = [wordnet_lemmatizer.lemmatize(t) for t in filtered_result]
    return lemmas

# %%
pd.set_option('display.max_colwidth', -1) # Setting this so we can see the full content of cells
tweets['normalized_tweet'] = tweets.Text.apply(normalizer)
tweets[['Text','normalized_tweet']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Text  \
# 0  If you are ever in Stockholm, these two museums, which are right next to each other, are a must. The vasa is a ship that was pulled from the icy waters and is completely preserved and very ornate. If you are ever in I recommend an afternoon at these museums.
# 1  Really interesting and so well organised with enough information but not too much! The ship itself is fascinating and I appreciated the exhibition focusing on the women's roles.
# 2  We planned 2 hours for Vasa but it was so interesting we forgot to leave. Vasa it's a MUST in Stocholm. You can learn all about the fully intact 17th century ship and about Sweden's history.
# 3  It was a very nice experience being there.The ship was huge and astonishing and u can see it from different heights and angles.All the was built around the ship and the story is very interesting.You can go there for sure ,the fee is around 15 euro.There were also some rooms/walls with things related to the ship which had their one interest!Also there is some guides appearing every 30 minutes making their guided tours every 30 minutes in a lot of languages(not greek unfortunately).
# 4  Travelling with my 11 year old and wanted to do something that “ ticked all the boxes “ . Whilst he had reservations , it was thoroughly enjoyed . Whilst there were not many people due to the world wide virus issue , there staff were extremely interesting and informative . It is one heck of a story including the nature of the sinking , recovery, restoration , preservation etc . Recommend it for anyone remotely interested in this kind of stuff . Allocate at least 3 hours for this and that was without allowing for queues .
#
#                                                                                                                                                                                                                                                                                                                                                                          normalized_tweet
# 0  [ever, stockholm, two, museum, right, next, must, vas, ship, pulled, icy, water, completely, preserved, ornate, ever, recommend, afternoon, museum]
# 1  [well, organised, enough, information, much, ship, fascinating, appreciated, exhibition, focusing, woman, role]
# 2  [hour, vas, interesting, forgot, leave, vas, must, stocholm, learn, fully, intact, th, century, ship, sweden, history]
# 3  [nice, experience, ship, huge, astonishing, u, see, different, height, angle, built, around, ship, story, interesting, go, sure, fee, around, euro, also, room, wall, thing, related, ship, one, interest, also, guide, appearing, every, minute, making, guided, tour, every, minute, lot, language, greek, unfortunately]
# 4  [year, old, wanted, something, ticked, box, whilst, reservation, thoroughly, enjoyed, whilst, many, people, due, world, wide, virus, issue, staff, extremely, interesting, informative, one, heck, story, including, nature, sinking, recovery, restoration, preservation, etc, recommend, anyone, remotely, interested, kind, stuff, allocate, least, hour, without, allowing, queue]

# %%
from nltk import ngrams

def ngrams(input_list):
    #onegrams = input_list
    bigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:]))]
    trigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:]))]
    fourgrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:], input_list[3:]))]
    return bigrams+trigrams
tweets['grams'] = tweets.normalized_tweet.apply(ngrams)
tweets[['grams']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        grams
# 0  [ever stockholm, stockholm two, two museum, museum right, right next, next must, must vas, vas ship, ship pulled, pulled icy, icy water, water completely, completely preserved, preserved ornate, ornate ever, ever recommend, recommend afternoon, afternoon museum, ever stockholm two, stockholm two museum, two museum right, museum right next, right next must, next must vas, must vas ship, vas ship pulled, ship pulled icy, pulled icy water, icy water completely, water completely preserved, completely preserved ornate, preserved ornate ever, ornate ever recommend, ever recommend afternoon, recommend afternoon museum]
# 1  [well organised, organised enough, enough information, information much, much ship, ship fascinating, fascinating appreciated, appreciated exhibition, exhibition focusing, focusing woman, woman role, well organised enough, organised enough information, enough information much, information much ship, much ship fascinating, ship fascinating appreciated, fascinating appreciated exhibition, appreciated exhibition focusing, exhibition focusing woman, focusing woman role]
# 2  [hour vas, vas interesting, interesting forgot, forgot leave, leave vas, vas must, must stocholm, stocholm learn, learn fully, fully intact, intact th, th century, century ship, ship sweden, sweden history, hour vas interesting, vas interesting forgot, interesting forgot leave, forgot leave vas, leave vas must, vas must stocholm, must stocholm learn, stocholm learn fully, learn fully intact, fully intact th, intact th century, th century ship, century ship sweden, ship sweden history]
# 3  [nice experience, experience ship, ship huge, huge astonishing, astonishing u, u see, see different, different height, height angle, angle built, built around, around ship, ship story, story interesting, interesting go, go sure, sure fee, fee around, around euro, euro also, also room, room wall, wall thing, thing related, related ship, ship one, one interest, interest also, also guide, guide appearing, appearing every, every minute, minute making, making guided, guided tour, tour every, every minute, minute lot, lot language, language greek, greek unfortunately, nice experience ship, experience ship huge, ship huge astonishing, huge astonishing u, astonishing u see, u see different, see different height, different height angle, height angle built, angle built around, built around ship, around ship story, ship story interesting, story interesting go, interesting go sure, go sure fee, sure fee around, fee around euro, around euro also, euro also room, also room wall, room wall thing, wall thing related, thing related ship, related ship one, ship one interest, one interest also, interest also guide, also guide appearing, guide appearing every, appearing every minute, every minute making, minute making guided, making guided tour, guided tour every, tour every minute, every minute lot, minute lot language, lot language greek, language greek unfortunately]
# 4  [year old, old wanted, wanted something, something ticked, ticked box, box whilst, whilst reservation, reservation thoroughly, thoroughly enjoyed, enjoyed whilst, whilst many, many people, people due, due world, world wide, wide virus, virus issue, issue staff, staff extremely, extremely interesting, interesting informative, informative one, one heck, heck story, story including, including nature, nature sinking, sinking recovery, recovery restoration, restoration preservation, preservation etc, etc recommend, recommend anyone, anyone remotely, remotely interested, interested kind, kind stuff, stuff allocate, allocate least, least hour, hour without, without allowing, allowing queue, year old wanted, old wanted something, wanted something ticked, something ticked box, ticked box whilst, box whilst reservation, whilst reservation thoroughly, reservation thoroughly enjoyed, thoroughly enjoyed whilst, enjoyed whilst many, whilst many people, many people due, people due world, due world wide, world wide virus, wide virus issue, virus issue staff, issue staff extremely, staff extremely interesting, extremely interesting informative, interesting informative one, informative one heck, one heck story, heck story including, story including nature, including nature sinking, nature sinking recovery, sinking recovery restoration, recovery restoration preservation, restoration preservation etc, preservation etc recommend, etc recommend anyone, recommend anyone remotely, anyone remotely interested, remotely interested kind, interested kind stuff, kind stuff allocate, stuff allocate least, allocate least hour, least hour without, hour without allowing, without allowing queue]

# %%
import collections
def count_words(input):
    cnt = collections.Counter()
    for row in input:
        for word in row:
            cnt[word] += 1
    return cnt

# %%
tweets[['grams']].apply(count_words)['grams'].most_common(100)
# Out:
# [('must see', 232),
#  ('guided tour', 224),
#  ('th century', 165),
#  ('worth visit', 155),
#  ('maiden voyage', 143),
#  ('well worth', 129),
#  ('well preserved', 102),
#  ('vas ship', 87),
#  ('see ship', 86),
#  ('well done', 84),
#  ('see stockholm', 82),
#  ('vas museum', 82),
#  ('year old', 81),
#  ('old ship', 74),
#  ('history ship', 72),
#  ('around ship', 67),
#  ('must see stockholm', 67),
#  ('year ago', 66),
#  ('visit stockholm', 65),
#  ('highly recommend', 65),
#  ('well worth visit', 63),
#  ('ship sank', 63),
#  ('definitely worth', 59),
#  ('must visit', 58),
#  ('free guided', 53),
#  ('highly recommended', 52),
#  ('free guided tour', 52),
#  ('ship amazing', 52),
#  ('free tour', 51),
#  ('century ship', 50),
#  ('spent hour', 50),
#  ('visit vas', 48),
#  ('would recommend', 47),
#  ('spend hour', 47),
#  ('couple hour', 46),
#  ('th century ship', 45),
#  ('sank maiden', 45),
#  ('ship well', 44),
#  ('sank maiden voyage', 44),
#  ('story behind', 43),
#  ('gift shop', 43),
#  ('ship vas', 43),
#  ('built around', 42),
#  ('one best', 42),
#  ('tour guide', 42),
#  ('visiting stockholm', 41),
#  ('make sure', 40),
#  ('different level', 38),
#  ('ship sunk', 38),
#  ('story ship', 38),
#  ('lot information', 38),
#  ('viking ship', 37),
#  ('view ship', 36),
#  ('short film', 36),
#  ('war ship', 34),
#  ('size ship', 34),
#  ('ship built', 33),
#  ('well presented', 33),
#  ('really interesting', 33),
#  ('preserved ship', 33),
#  ('well laid', 33),
#  ('visit museum', 33),
#  ('ship impressive', 32),
#  ('tour english', 32),
#  ('place visit', 31),
#  ('sheer size', 31),
#  ('sunk maiden', 31),
#  ('ship story', 30),
#  ('sunk maiden voyage', 30),
#  ('story vas', 30),
#  ('definitely worth visit', 30),
#  ('amazing see', 29),
#  ('huge ship', 29),
#  ('walk around', 29),
#  ('ship history', 29),
#  ('ship huge', 28),
#  ('ship interesting', 28),
#  ('year later', 28),
#  ('different language', 28),
#  ('swedish history', 27),
#  ('history vas', 27),
#  ('mary rose', 27),
#  ('amazing ship', 27),
#  ('ship also', 27),
#  ('least hour', 26),
#  ('really enjoyed', 26),
#  ('see vas', 26),
#  ('english tour', 26),
#  ('worth seeing', 26),
#  ('awe inspiring', 25),
#  ('ever seen', 25),
#  ('two hour', 25),
#  ('worth time', 25),
#  ('ship preserved', 25),
#  ('ship really', 25),
#  ('tour group', 25),
#  ('hundred year', 24),
#  ('audio guide', 24),
#  ('worth visiting', 24),
#  ('djurg rden', 24)]
