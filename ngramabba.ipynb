# %%
import pandas as pd
tweets = pd.read_csv("/Users/maxrojas/Desktop/BI/3period/datasets/abba.csv")
list(tweets.columns.values)
# Out:
# ['Text',
#  'Title',
#  'Rating',
#  'DateOfExperience',
#  'DateOfReview',
#  'Username',
#  'UserLocation',
#  'UserContribution',
#  'UserLikes']

# %%
tweets['Rating']=tweets['Rating'].fillna("")
tweets['DateOfExperience']=tweets['DateOfExperience'].fillna("")
tweets['UserLocation']=tweets['UserLocation'].fillna("")
tweets['UserContribution']=tweets['UserContribution'].fillna("")
tweets['UserLikes']=tweets['UserLikes'].fillna("")
tweets['Title']=tweets['Title'].fillna("")

tweets.head()
# Out:
#                                                 Text  \
# 0  ABBA the museum is cool place to visit if inte...
# 1  If you are or were an ABBA fan, you must go an...
# 2  This is a must for Tourists to Stockholm. I wa...
# 3  Walk in Dance out........they aren't joking. N...
# 4  Words cannot express how much this means to so...
#
#                           Title  Rating DateOfExperience DateOfReview  \
# 0      Must for ABBA enthusiast      50     January 2020       mar-20
# 1  Leuk om te gezien te hebben.      40       March 2020       mar-17
# 2                     2nd visit      50       April 2019       mar-16
# 3                     A must do      50    December 2019       mar-13
# 4           The Best Experience      50       March 2020       mar-11
#
#    Username                 UserLocation UserContribution UserLikes
# 0  ErvastiR             Tallinn, Estonia               33        15
# 1  AvanToll  Driebergen, The Netherlands              168        36
# 2  Ashley B      Bakersfield, California               81        17
# 3   Simon H    Salisbury, United Kingdom              402       155
# 4   Jayne C                                             9

# %%
stop = ['Slottstradgarden', 'ABBA','museum', 'abba', 'abb', 'vas', 'vasa' 'stockholm', 'slottstradgarden ', 'Stockholm', 'Museum', 'museums', 'museet','museum ','stockholm']
tweets['Text'] = tweets['Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
tweets.head()
# Out:
#                                                 Text  \
# 0  the is cool place to visit if interested in th...
# 1  If you are or were an fan, you must go and see...
# 2  This is a must for Tourists to Stockholm. I wa...
# 3  Walk in Dance out........they aren't joking. N...
# 4  Words cannot express how much this means to so...
#
#                           Title  Rating DateOfExperience DateOfReview  \
# 0      Must for ABBA enthusiast      50     January 2020       mar-20
# 1  Leuk om te gezien te hebben.      40       March 2020       mar-17
# 2                     2nd visit      50       April 2019       mar-16
# 3                     A must do      50    December 2019       mar-13
# 4           The Best Experience      50       March 2020       mar-11
#
#    Username                 UserLocation UserContribution UserLikes
# 0  ErvastiR             Tallinn, Estonia               33        15
# 1  AvanToll  Driebergen, The Netherlands              168        36
# 2  Ashley B      Bakersfield, California               81        17
# 3   Simon H    Salisbury, United Kingdom              402       155
# 4   Jayne C                                             9

# %%
import re, nltk
from nltk.stem import WordNetLemmatizer

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
wordnet_lemmatizer = WordNetLemmatizer()

def normalizer(tweet):
    only_letters = re.sub("[^a-zA-Z]", " ",tweet) 
    tokens = nltk.word_tokenize(only_letters)[2:]
    lower_case = [l.lower() for l in tokens]
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    lemmas = [wordnet_lemmatizer.lemmatize(t) for t in filtered_result]
    return lemmas

# %%
pd.set_option('display.max_colwidth', -1) # Setting this so we can see the full content of cells
tweets['normalized_tweet'] = tweets.Text.apply(normalizer)
tweets[['Text','normalized_tweet']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Text  \
# 0  the is cool place to visit if interested in their music . Lot of information available, illustrative pics, genuine gold records and authentic show costumes. Visited already for second time and did not get tired of the theme. The premises are a bit rough around the edges, mainly because is situated in a cellar. should gradually start thinking about face-lift otherwise great business idea will not carry the further in the future. All in all, nostalgic to visit. Highly recommend.
# 1  If you are or were an fan, you must go and see this with the stories behind the band members: before, during, and after their succesfull period. Lots of displays of stuff and pictures. And you actually participate in their songs...__
# 2  This is a must for Tourists to Stockholm. I was overwhelmed by the experience. Thus I returned last year again. Ranks right up there along with the Vassa ship.
# 3  Walk in Dance out........they aren't joking. Not a massive Abba fan, well thats what I thought........great fun. Even did the bit where you can sing on stage with the group! I was surprised by the very eclectic mix on people , young to old and from totally different backgrounds! Forget male bravado, every one is tapping there foot, humming and just enjoying it. Even a guy I saw who would have looked better placed having fights with biker gangs!......still singing along to himself!
# 4  Words cannot express how much this means to someone who has been an fan for so long, so I won't try, instead I will tell you how my much younger friends enjoyed our day, they loved the interactive experience and danced and sang for the whole time, they certainly walked in and danced out!!
#
#                                                                                                                                                                                                                                                                                                                                                                          normalized_tweet
# 0  [cool, place, visit, interested, music, lot, information, available, illustrative, pic, genuine, gold, record, authentic, show, costume, visited, already, second, time, get, tired, theme, premise, bit, rough, around, edge, mainly, situated, cellar, gradually, start, thinking, face, lift, otherwise, great, business, idea, carry, future, nostalgic, visit, highly, recommend]
# 1  [fan, must, go, see, story, behind, band, member, succesfull, period, lot, display, stuff, picture, actually, participate, song]
# 2  [must, tourist, stockholm, overwhelmed, experience, thus, returned, last, year, rank, right, along, vassa, ship]
# 3  [dance, joking, massive, abba, fan, well, thats, thought, great, fun, even, bit, sing, stage, group, surprised, eclectic, mix, people, young, old, totally, different, background, forget, male, bravado, every, one, tapping, foot, humming, enjoying, even, guy, saw, would, looked, better, placed, fight, biker, gang, still, singing, along]
# 4  [express, much, mean, someone, fan, long, try, instead, tell, much, younger, friend, enjoyed, day, loved, interactive, experience, danced, sang, whole, time, certainly, walked, danced]

# %%
from nltk import ngrams

def ngrams(input_list):
    #onegrams = input_list
    bigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:]))]
    trigrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:]))]
    fourgrams = [' '.join(t) for t in list(zip(input_list, input_list[1:], input_list[2:], input_list[3:]))]
    return bigrams+trigrams
tweets['grams'] = tweets.normalized_tweet.apply(ngrams)
tweets[['grams']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# %%
import collections
def count_words(input):
    cnt = collections.Counter()
    for row in input:
        for word in row:
            cnt[word] += 1
    return cnt

# %%
tweets[['grams']].apply(count_words)['grams'].most_common(100)
# Out:
# [('audio guide', 365),
#  ('abba fan', 305),
#  ('gift shop', 254),
#  ('worth visit', 208),
#  ('sing dance', 201),
#  ('sing along', 198),
#  ('swedish music', 193),
#  ('lot fun', 190),
#  ('great fun', 185),
#  ('well worth', 178),
#  ('interactive exhibit', 176),
#  ('lot interactive', 167),
#  ('interactive activity', 165),
#  ('singing dancing', 156),
#  ('hall fame', 156),
#  ('fun interactive', 152),
#  ('band member', 150),
#  ('mamma mia', 148),
#  ('much fun', 141),
#  ('recording studio', 139),
#  ('big fan', 138),
#  ('interactive thing', 136),
#  ('visit museum', 133),
#  ('must see', 126),
#  ('music hall', 119),
#  ('music hall fame', 119),
#  ('couple hour', 118),
#  ('huge fan', 115),
#  ('dancing queen', 115),
#  ('great time', 115),
#  ('credit card', 113),
#  ('interactive part', 110),
#  ('th member', 109),
#  ('really enjoyed', 105),
#  ('audio tour', 105),
#  ('swedish music hall', 104),
#  ('well done', 103),
#  ('mama mia', 101),
#  ('would recommend', 99),
#  ('interactive display', 99),
#  ('like abba', 98),
#  ('music video', 98),
#  ('place visit', 97),
#  ('fan abba', 95),
#  ('abba music', 95),
#  ('buy ticket', 93),
#  ('must visit', 92),
#  ('ticket online', 89),
#  ('love abba', 88),
#  ('make sure', 86),
#  ('memory lane', 82),
#  ('song contest', 81),
#  ('original costume', 79),
#  ('highly recommend', 77),
#  ('member abba', 77),
#  ('fifth member', 76),
#  ('well worth visit', 76),
#  ('abba song', 75),
#  ('abba museum', 74),
#  ('entrance fee', 74),
#  ('eurovision song', 74),
#  ('eurovision song contest', 71),
#  ('fan must', 70),
#  ('visit stockholm', 70),
#  ('lot memorabilia', 70),
#  ('lot information', 69),
#  ('interactive stuff', 69),
#  ('interactive experience', 67),
#  ('many people', 67),
#  ('good fun', 64),
#  ('lot see', 63),
#  ('great place', 63),
#  ('year old', 63),
#  ('member group', 62),
#  ('pop music', 61),
#  ('member band', 61),
#  ('singing along', 60),
#  ('way spend', 60),
#  ('spend hour', 60),
#  ('much see', 60),
#  ('gold record', 58),
#  ('good time', 58),
#  ('really fun', 58),
#  ('definitely worth', 56),
#  ('history band', 56),
#  ('see costume', 56),
#  ('accept cash', 56),
#  ('great interactive', 55),
#  ('well laid', 55),
#  ('highly recommended', 55),
#  ('many interactive', 54),
#  ('scan ticket', 54),
#  ('entry fee', 54),
#  ('hop hop', 54),
#  ('interactive museum', 54),
#  ('vas museum', 54),
#  ('love music', 53),
#  ('stage sing', 53),
#  ('get stage', 52),
#  ('history group', 52)]
